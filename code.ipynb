# %%
# !pip3.11 install Flask-Session Flask-SQLAlchemy
# Out:
# ...
#                                               0.0/2.1 MB ? eta -:--:--
#                                               0.0/2.1 MB 960.0 kB/s eta 0:00:03
#      -                                        0.1/2.1 MB 975.2 kB/s eta 0:00:03
#      -                                        0.1/2.1 MB 573.4 kB/s eta 0:00:04
#      --                                       0.2/2.1 MB 833.5 kB/s eta 0:00:03
#      ---                                      0.2/2.1 MB 701.4 kB/s eta 0:00:03
#      ----                                     0.2/2.1 MB 769.9 kB/s eta 0:00:03
#      -----                                    0.3/2.1 MB 907.8 kB/s eta 0:00:02
#      ------                                   0.3/2.1 MB 922.8 kB/s eta 0:00:02
#      ------                                   0.3/2.1 MB 830.3 kB/s eta 0:00:03
#      -------                                  0.4/2.1 MB 946.4 kB/s eta 0:00:02
#      ---------                                0.5/2.1 MB 1.0 MB/s eta 0:00:02
# ...

# %% [markdown]
# # MySQL Queries
#
# CREATE DATABASE IF NOT EXISTS recommendation_system;
# CREATE TABLE IF NOT EXISTS products (
#         product_id INT AUTO_INCREMENT PRIMARY KEY,
#         product_name VARCHAR(255),
#         category VARCHAR(255),
#         image_url VARCHAR(255)
#     );
# CREATE TABLE IF NOT EXISTS visits (
#         visit_id INT AUTO_INCREMENT PRIMARY KEY,
#         user_id INT,
#         product_id INT,
#         visit_count INT,
#         timestamp TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#         FOREIGN KEY (user_id) REFERENCES users(user_id),
#         FOREIGN KEY (product_id) REFERENCES products(product_id)
#     );
# CREATE TABLE IF NOT EXISTS purchases (
#         purchase_id INT AUTO_INCREMENT PRIMARY KEY,
#         user_id INT,
#         product_id INT,
#         purchase_count INT,
#         timestamp TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#         FOREIGN KEY (user_id) REFERENCES users(user_id),
#         FOREIGN KEY (product_id) REFERENCES products(product_id)
#     );
#
#
# INSERT INTO products (product_name, category, image_url) VALUES
#     ('Phone A', 'Phones', 'phone_a.jpg'),
#     ('Laptop X', 'Laptops', 'laptop_x.jpg'),
#     ('Microphone M', 'Microphones', 'microphone_m.jpg');
